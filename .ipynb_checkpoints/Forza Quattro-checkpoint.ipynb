# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ROWS    = 6                    # Number of rows in the board
COLS    = 7                    # Number of columns in the board
INPUT   = 2*(ROWS*COLS) + 1    # Number of neurons in the input layer
POPU    = 24                   # Population size ( for the genetic algo )
EPOCHS  = 30                   # Number of generations ( for the genetic algo )
LIFE    = 10                   # Number of ...( for the genetic algo )
MUTAT   = 1                    # Average mutation strenght ( for the genetic algo )
COLORS  = {'Red':1, 'Yellow':2}
PLAYERS = ['Draw', 'Red', 'Yellow']

# %%
# Board functions

def NewTable():
    return np.zeros(shape=(ROWS,COLS))

def DropIn(table, j, color):
     
    ok = ( not IsColFull(table,j ) )
    for i in range(1,ROWS+1):
        if table[ROWS-i][j]==0:
            table[ROWS-i][j] = color
            break

    return table, ok

def IsFull(board):
    return ( len(board[board==0]) == 0 )

def IsColFull(board, j):
    return ( len(board[:,j][board[:,j]==0]) == 0 )

def DrawBoard(table):
    for i in range(0,ROWS):
        for j in range(0,COLS):
            pedina = table[ROWS-i-1][j]
            if   pedina == 1: color='red'
            elif pedina == 2: color='yellow'
            else : color='white'
            circle = plt.Circle((j,i), 0.4, fc=color)
            plt.gca().add_patch(circle)
    plt.axis('scaled')
    

# Game Evaluation functions ( who won? )

def CheckRow(i, table):
    row = table[i]
    for j in range(0,COLS-4+1):
        x = np.prod(row[j:j+4])
        if x==1**4 :
            return 1     
        elif x==2**4 :
            return 2
    return 0

def CheckColumn(j, table):
    col = table[:,j]
    for i in range(0,ROWS-4+1):
        x = np.prod(col[i:i+4])
        if x==1**4 :
            return 1
        elif x==2**4 :
            return 2
    return 0

def CheckDiagonal(i, j, table, anti=False):
    
    direction = 1 - 2*int(anti)
    diag = np.zeros(4)
    for k in range(0,4):
        diag[k] = table[ i+k, j + direction * k ]
    x = np.prod(diag)

    if x==1**4 :
        return 1
    elif x==2**4 :
        return 2
    else :
        return 0
    
def Winner(table):
    for i in range(0,ROWS):
        x = CheckRow(i, table)
        if x: return x
        
        for j in range(0,COLS):
            x = CheckColumn(j, table)
            if x: return x
            
            if i < ROWS-4+1:
                if j < COLS-4+1:
                    x = CheckDiagonal(i,j, table)
                    if x: return x

                if j >= COLS-4:
                    x = CheckDiagonal(i,j, table, anti=True)
                    if x: return x
    return x

def AnnounceWinner(board):
    x = Winner(board)
    if x > 0: print('{0} won!'.format(PLAYERS[x]))

# %%
# Neural Net functions

def Sigmoid(x,deriv=False):
    if(deriv==True):
        return x*(1-x)
    return 1/(1+np.exp(-x))

def Input(board):
    X1  = board.reshape(COLS*ROWS).copy()
    X1[X1==2] = 0
    X2  = board.reshape(COLS*ROWS).copy()
    X2[X2==1] = 0   
    X2[X2==2] = 1  
    X  = np.append(1, X1)
    X  = np.append(X, X2)
    return X

def Response(board, w, full=False):
    
    X = Input(board)
    
    Y  = np.zeros(COLS)
    for i in range(0, COLS):
        if ( not IsColFull(board,i) ):
            Y[i] = Sigmoid( w[i].dot(X) )
    
    if full : return Y
    return np.argmax(Y)

def MakeMove(board, w1, p):
    board, ok = DropIn(board, Response(board, w1), p)
    return board


# Genetic Algo functions

def RandomWeights():
    return np.random.uniform(low=-1, high=1, size=(COLS, INPUT))
        
def Mutate(w1):
    return w1 + MUTAT * np.random.normal(size=(COLS, INPUT))

def Reward(winner,number_of_moves):
    if   winner==0: return 0
    elif winner==1: return 1
    else          : return -1

def Offspring(w1, w2):
    
    new = np.zeros(shape=(POPU, COLS, INPUT))
    for i in range(0, POPU-2):
        if   i%3==0: new[i] = Mutate(w1)
        elif i%3==1: new[i] = Mutate(w2)
        elif i%3==2: new[i] = np.append(w1[:ROWS/2], w2[ROWS/2:], axis=0)
        elif i%3==3: new[i] = np.append(w2[:ROWS/2], w1[ROWS/2:], axis=0)
        
    new[-1] = w1
    new[-2] = w2
    return new

# %%
def LinearChallenge(w1, j):
    board = NewTable()
    i = 0
    moves = []
    while ( not IsFull(board) ):
    
        j = j % COLS
            
        moves.append(Response(board, w1))
        board, ok = DropIn(board, moves[i], 1)
        if (not ok) :
            x = 2
            break
        x = Winner(board)
        if x == 1 : break
            
        board, ok = DropIn(board, j, 2)
        x = Winner(board)
        if x == 2 : break
            
        i += 1
        j += 1
    return [x,i,board, moves]

def ConstantChallenge(w1, j):
    board = NewTable()
    j = j % COLS
    i = 0
    moves = []
    while ( not IsFull(board) ):
            
        moves.append(Response(board, w1))
        board, ok = DropIn(board, moves[i], 1)
        if (not ok) :
            x = 2
            break
        x = Winner(board)
        if x == 1 : break
            
        board, ok = DropIn(board, j, 2)
        x = Winner(board)
        if x == 2 : break
            
        i += 1
    return [x,i,board, moves]

def Challenge(w1,w2):
    board = NewTable()
    i = 0
    moves = []
    while ( not IsFull(board) ):
        #print(i)
        #if i > 50 : return [x,i,board]
        moves.append(Response(board, w1))
        board, ok = DropIn(board, moves[i], 1)
        if (not ok) :
            x = 2
            break
        x = Winner(board)
        if x == 1 : break
        board, ok = DropIn(board, Response(board, w2), 2)
        if (not ok) :
            x = 0
            break
        x = Winner(board)
        if x == 2 : break
        
        i += 1
    return [x,i,board, moves]


def PickBest(w):
    fits = np.zeros(POPU)

    for p in range(0, POPU):
        w1 = w[p]
        fits[p] = FitnessOf(w1,w)

    best   = np.argmax(fits)
    w1 = w[best]
    best_f = fits[best].copy()
    fits[best] = 0
    best   = np.argmax(fits)
    w2 = w[best]
    return w1, w2, best_f


def FitnessOf(w1, w):
    fitness = 0
    sample  = np.random.randint(0, len(w), size=LIFE)
    
    for j in range(0, LIFE):
        w2 = RandomWeights()
        x, i, board, moves = Challenge(w1,w2)
        fitness += Reward(x,i)
            
    for j in range(0,LIFE):
        x, i, board, moves = ConstantChallenge(w1, j)
        fitness += Reward(x,i)
            
    for j in range(0,LIFE):
        x, i, board, moves = LinearChallenge(w1, j)
        fitness += Reward(x,i)
        
    for p in sample:
        w2 = w[p]
        x, i, board, moves = Challenge(w1,w2)
        fitness += Reward(x,i)

    return fitness


# Random Game functions

def RandomMove(table, moves, x):
    
    ok = False
    while(not ok):
        i = np.random.randint(0, COLS)
        table, ok = DropIn(table,i,1)
    moves.append(i)
    x = Winner(board)
    if x > 0 : return table, moves, x
    
    ok = False  
    while(not ok):
        i = np.random.randint(0, COLS)
        table, ok = DropIn(table,i,2)
    moves.append(i)
    x = Winner(board)
    return table, moves, x


def RandomMatch(table, moves, x):
    for i in range(0,int(ROWS*COLS/2) ):
        table, moves, x = RandomMove(table, moves, x)
        if x > 0 : break
    return table, moves, x


# ???

def AnotherChance(board, moves, new):
    
    table = board.copy()
    
    j   = moves[-1]
    i   = ROWS - len( np.trim_zeros(table[:,j]) )
    table[i,j] = 0
    
    j   = moves[-2]
    i   = ROWS - len( np.trim_zeros(table[:,j]) ) 
    table[i,j] = 0

    j   = new
    i   = ROWS - len( np.trim_zeros(table[:,j]) ) - 1
    table[i,j] = 1
    
    j   = moves[-1]
    i   = ROWS - len( np.trim_zeros(table[:,j]) ) - 1
    table[i,j] = 2
    
    x = Winner(table)
    moves = moves[:-2] + [ new, moves[-1] ]
    return table, moves, x

# %%
# %%time
train = []

for i in range(0,1000):
    board, moves, x = NewTable(), [], 0
    board, moves, x = RandomMatch(board, moves, x)
    if x > 1: train.append([board, moves].copy())
        
print(len(train))

# %%
# %%time
E = 100
#w   = np.random.uniform(low=-1, high=1, size=(POPU, COLS, INPUT))
w  = Offspring(w1,w2)
for e in range(0,E):
    fits = []
    for p in range(0,POPU):
        fitness = 0
        for (board, moves) in train:
            board2, moves2, x2 = AnotherChance(board, moves, Response(board, w[p]) )
            fitness += (x2+1)%3
        fits.append(fitness)
    print('Generation {0}, Fitness = {1}'.format(e, np.max(fits)))
    
    best   = np.argmax(fits)
    w1 = w[best]
    fits[best] = 0
    best   = np.argmax(fits)
    w2 = w[best]
    #w2 = RandomWeights()
    w  = Offspring(w1,w2)
# Out:
# Generation 0, Fitness = 276
# Generation 1, Fitness = 276
# Generation 2, Fitness = 276
# Generation 3, Fitness = 276
# Generation 4, Fitness = 276
# Generation 5, Fitness = 276
# Generation 6, Fitness = 276
# Generation 7, Fitness = 276
# Generation 8, Fitness = 276
# Generation 9, Fitness = 276
# Generation 10, Fitness = 276
# Generation 11, Fitness = 276
# Generation 12, Fitness = 276
# Generation 13, Fitness = 276
# Generation 14, Fitness = 276
# Generation 15, Fitness = 276
# Generation 16, Fitness = 276
# Generation 17, Fitness = 276
# Generation 18, Fitness = 276
# Generation 19, Fitness = 276
# Generation 20, Fitness = 276
# Generation 21, Fitness = 276
# Generation 22, Fitness = 276
# Generation 23, Fitness = 276
# Generation 24, Fitness = 276
# Generation 25, Fitness = 276
# Generation 26, Fitness = 276
# Generation 27, Fitness = 276
# Generation 28, Fitness = 276
# Generation 29, Fitness = 276
# Generation 30, Fitness = 276
# Generation 31, Fitness = 276
# Generation 32, Fitness = 276
# Generation 33, Fitness = 276
# Generation 34, Fitness = 276
# Generation 35, Fitness = 276
# Generation 36, Fitness = 276
# Generation 37, Fitness = 276
# Generation 38, Fitness = 276
# Generation 39, Fitness = 276
# Generation 40, Fitness = 276
# Generation 41, Fitness = 276
# Generation 42, Fitness = 276
# Generation 43, Fitness = 276
# Generation 44, Fitness = 276
# Generation 45, Fitness = 276
# Generation 46, Fitness = 276
# Generation 47, Fitness = 276
# Generation 48, Fitness = 276
# Generation 49, Fitness = 276
# Generation 50, Fitness = 276
# Generation 51, Fitness = 276
# Generation 52, Fitness = 276
# Generation 53, Fitness = 276
# Generation 54, Fitness = 276
# Generation 55, Fitness = 276
# Generation 56, Fitness = 276
# Generation 57, Fitness = 276
# Generation 58, Fitness = 276
# Generation 59, Fitness = 276
# Generation 60, Fitness = 276
# Generation 61, Fitness = 276
# Generation 62, Fitness = 276
# Generation 63, Fitness = 276
# Generation 64, Fitness = 276
# Generation 65, Fitness = 276
# Generation 66, Fitness = 276
# Generation 67, Fitness = 276
# Generation 68, Fitness = 276
# Generation 69, Fitness = 276
# Generation 70, Fitness = 276
# Generation 71, Fitness = 276
# Generation 72, Fitness = 276
# Generation 73, Fitness = 276
# Generation 74, Fitness = 276
# Generation 75, Fitness = 276
# Generation 76, Fitness = 276
# Generation 77, Fitness = 276
# Generation 78, Fitness = 276
# Generation 79, Fitness = 276
# Generation 80, Fitness = 276
# Generation 81, Fitness = 276
# Generation 82, Fitness = 276
# Generation 83, Fitness = 276
# Generation 84, Fitness = 276
# Generation 85, Fitness = 276
# Generation 86, Fitness = 276
# Generation 87, Fitness = 276
# Generation 88, Fitness = 276
# Generation 89, Fitness = 276
# Generation 90, Fitness = 276
# Generation 91, Fitness = 276
# Generation 92, Fitness = 276
# Generation 93, Fitness = 276
# Generation 94, Fitness = 276
# Generation 95, Fitness = 276
# Generation 96, Fitness = 276
# Generation 97, Fitness = 276
# Generation 98, Fitness = 276
# Generation 99, Fitness = 276
# Wall time: 17min 42s

# %%
board, moves = train[2]
DrawBoard(board)
moves[-2:]
# Out:
# [0, 4]

# %%
board2, moves2, x2 = AnotherChance(board, moves, 5)
DrawBoard(board2)
print('{0} won choosing {1}! \nThe opponent lost choosing {2}.'.format(PLAYERS[x2], moves2[-1], moves2[-2] ))
# Out:
# 3
# Draw won choosing 5!
# The opponent lost choosing 5.

# %%
# %%time
w   = np.random.uniform(low=-1, high=1, size=(POPU, COLS, INPUT))
#w = Offspring(w1,w2)
for e in range(0,EPOCHS):
    w1, w2, fit = PickBest(w)
    print('Epoch {0} ended with fitness {1}'.format(e, fit))
    w  = Offspring(w1,w2)
# Out:
# Epoch 0 ended with fitness 16.0
# Epoch 1 ended with fitness 26.0
# Epoch 2 ended with fitness 34.0
# Epoch 3 ended with fitness 30.0
# Epoch 4 ended with fitness 32.0
# Epoch 5 ended with fitness 34.0
# Epoch 6 ended with fitness 36.0
# Epoch 7 ended with fitness 34.0
# Epoch 8 ended with fitness 32.0
# Epoch 9 ended with fitness 32.0
# Epoch 10 ended with fitness 32.0
# Epoch 11 ended with fitness 24.0
# Epoch 12 ended with fitness 34.0
# Epoch 13 ended with fitness 28.0
# Epoch 14 ended with fitness 36.0
# Epoch 15 ended with fitness 30.0
# Epoch 16 ended with fitness 26.0
# Epoch 17 ended with fitness 32.0
# Epoch 18 ended with fitness 32.0
# Epoch 19 ended with fitness 34.0
# Epoch 20 ended with fitness 26.0
# Epoch 21 ended with fitness 36.0
# Epoch 22 ended with fitness 36.0
# Epoch 23 ended with fitness 38.0
# Epoch 24 ended with fitness 38.0
# Epoch 25 ended with fitness 36.0
# Epoch 26 ended with fitness 38.0
# Epoch 27 ended with fitness 34.0
# Epoch 28 ended with fitness 38.0
# Epoch 29 ended with fitness 36.0
# Wall time: 3min 48s

# %%
board = NewTable()
board = MakeMove(board, w1, 1)
DrawBoard(board)

# %%
board, ok = DropIn(board, 2, 2)
board     = MakeMove(board, w1, 1)
DrawBoard(board)

# %%
pd.DataFrame(w1).to_hdf('Forza','Trained')

# %%
w0 = pd.read_hdf('Forza','Trained').as_matrix()

# %%
plt.plot(w1.reshape(COLS*INPUT))
plt.plot(Mutate(w1).reshape(COLS*INPUT))

# %%
plt.plot(w2.reshape(COLS*INPUT))
plt.plot(Mutate(w2).reshape(COLS*INPUT))
